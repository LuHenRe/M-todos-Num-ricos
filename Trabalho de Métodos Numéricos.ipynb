# %% [markdown]
# # Trabalho de Métodos Numéricos

# %% [markdown]
# 1) Implemente em Python uma biblioteca contendo as funções:
#
#    i) Que resolva um sistema triangular;
#
#    ii) Que resolva um sistema triangular inferior;
#
#    iii) Que faça a eliminação de Gauss
#
# 2) Escolha um problema cuja solução envolva resolver um sistema linear de no mínimo 5 icógnitas. Use o Jupyter Notebook para apresentá-lo, formulá-lo e com a biblioteca do item 1, resolva o problema.
