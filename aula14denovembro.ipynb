# %% [markdown]
# $$ I = \int_{5}^{1} {x-1}^ {0.5} dx $$

# %%
def f(x): 
    return( (x-1)**0.5)

# %%
f(5)
# Out:
# 2.0

# %%
a = 5
b= 1 
y0 = f(a)
y1 = f(b) 
h = a - b

# %%
I = h/2 * (y0+y1)
I
# Out:
# 4.0

# %%
def trapezio_s (h, y0, y1):
    I = h*(y0+y1)/2 
    return (I)

# %%
I = trapezio_s (4,f(a), f(b))
I
# Out:
# 4.0

# %% [markdown]
# Calcular a mesma função com n = 4

# %%
I1 = trapezio_s (1, f(1),f(2))
I2 = trapezio_s (1, f(2), f(3))
I3 = trapezio_s (1, f(3), f(4))
I4 = trapezio_s (1, f(4), f(5))

# %%
I = I1 + I2 + I3 + I4 
I
# Out:
# 5.146264369941973

# %%
def trapezio_s (h, y0, y1):
    I = h * (y0+y1) / 2 
    return (I) 
    h = (x1 - x0)/n 
    X = np.zeros
    for i in range (n)
    I = trapezio_s (h, f(x+h))
    x =
