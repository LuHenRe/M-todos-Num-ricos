# %% [markdown]
# # Aula 7 - Métodos Numéricos

# %% [markdown]
# ### Métodos baseados em aproximação linear

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def funcao(x): return 2 * x ** 3 - np.cos(x + 1) - 4

# %%
def secante(f, x0, x1, tol=1e-6, max_iter=100):
#"""
#Encontra a raiz, no intervalo [x0, x1], da equação definida em fParada: no máximo, max_iter, iteracões ou diferença entre
#os limites do intervalo menor que tol.
#"""
    for i in range(max_iter):
        x2 = x1 - f(x1) * (x1 - x0) / (f(x1) - f(x0))
        if abs(x2 - x1) < tol:
            return x2
            #return f'raiz = {x2}\nvalor de f na raiz: {f(x1)}'
        x0 = x1
        x1 = x2
    return None # Não converge

print(secante(funcao2, 0, 2, max_iter=100))
print(funcao2(secante(funcao2, 0, 2, max_iter=100)))
# Out:
# 1.9612918091061555
# 1.7763568394002505e-14

# %%
def grafico(f, a, b):
    x = np.linspace(a, b, 100)
    y = f(x)
    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Gráfico de f(x) = 2x³ - cos(x + 1) - 4')
    plt.grid(True)
    plt.show()
grafico(funcao, 0, 2)

# %%
def secante(f, a, b, tol=1e-6, max_iter=100):
#"""
#Encontra a raiz, no intervalo [x0, x1], da equação definida 
#em fParada: no máximo, max_iter, iteracões ou diferença entre
#os limites do intervalo menor que tol.
#"""
    for i in range(max_iter):
        c = (a * f(b) - b * f(a)) / (f(b) - f(a))
        if abs(f(c)) < tol:
            return c
        a = b
        b = c
    return None # Não converge

raiz = secante(funcao, 0, 2, tol=1e-3, max_iter=10)
print('raiz:', raiz)
print('função da raiz:', funcao(raiz))
# Out:
# raiz: 1.1952641615558735
# função da raiz: -9.075006728087587e-05

# %%
def funcao2(x): return 2 * x ** 4 + 4 * x ** 3 - 11 * x ** 2 - 14 * x + 10

# %%
raiz = secante(funcao2, -3, -2, tol=1e-6, max_iter=10)
print('raiz:', raiz)
print('função da raiz:', funcao2(raiz))
# Out:
# raiz: -1.6504209968014592
# função da raiz: -3.552713678800501e-15
